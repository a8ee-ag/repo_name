# %% [markdown]
# <a href="https://colab.research.google.com/github/a8ee-ag/repo_name/blob/hw_2/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Chocolate:
  def __init__(self, price: float, fill: str = ""):
    if price <= 0:
      raise ValueError("Price of the bar must be above Zero")
    self.price = price
    self.fill = fill

  def show_my_chocolate(self):
    if self.fill:
      print(f"Bar have filling: {self.fill}")
    else:
      print("Its regular bar")

  def __str__(self):
    return f"Chocolate bar. Price is {self.price} rubs"

# %%
class Chocolate:
  def __init__(self, price: float, fill: str = ""):
    if price <= 0:
      raise ValueError("Price of the bar must be above Zero")
    self.price = price
    self.fill = fill

  def show_my_chocolate(self):
    if self.fill:
      print(f"Bar have filling: {self.fill}")
    else:
      print("Its regular bar")

  def __str__(self):
    return f"Chocolate bar. Price is {self.price} rubs"


if __name__ == "__main__":

  nutty = Chocolate(99.0, "hazelnut")
  print(nutty)
  nutty.show_my_chocolate()

  print("-" * 30)

  berry = Chocolate(120.0, "cranberry")
  print(berry)
  berry.show_my_chocolate()

  print("-" * 30)

  plain = Chocolate(75.5)
  print(plain)
  plain.show_my_chocolate()

  print("-" * 30)

  try:
    broken = Chocolate(-10.0, "raisins")
  except ValueError as e:
    print(f"Error: {e}")
# Out:
# Chocolate bar. Price is 99.0 rubs
# Bar have filling: hazelnut
# ------------------------------
# Chocolate bar. Price is 120.0 rubs
# Bar have filling: cranberry
# ------------------------------
# Chocolate bar. Price is 75.5 rubs
# Its regular bar
# ------------------------------
# Error: Price of the bar must be above Zero
